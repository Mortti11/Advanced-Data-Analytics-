# %% [markdown]
# ### PGCB Hourly Generation Dataset (Bangladesh)
# This dataset, published by the Power Grid Company of Bangladesh (PGCB), provides hourly records of electricity generation, demand, and loadshedding across the national grid.<br>
# Source: https://archive.ics.uci.edu/dataset/1175/pgcb+hourly+generation+dataset+(bangladesh)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_selection import mutual_info_regression
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# <h3><center>Loading and exploring the DS<h3>

# %%
df = pd.read_excel("PGCB_date_power_demand.xlsx")
df.head()
# Out:
#              datetime  generation_mw  demand_mw  load_shedding   gas  \
# 0 2015-04-19 22:00:00         6323.0       6323              0     0
# 1 2015-04-19 21:00:00         6667.0       6667              0     0
# 2 2015-04-19 19:00:00         6897.0       6897              0  4415
# 3 2015-04-19 18:30:00         6933.0       6933              0  4423
# 4 2015-04-19 18:00:00         6874.0       6874              0  4319
#
#    liquid_fuel  coal  hydro  solar  wind  india_bheramara_hvdc  india_tripura  \
# 0            0     0      0    NaN   NaN                     0              0
# 1            0     0      0    NaN   NaN                     0              0
# 2         1836   161     41    NaN   NaN                   444              0
# 3         1862   159     45    NaN   NaN                   444              0
# 4         1892   155     65    NaN   NaN                   443              0
#
#    india_adani  nepal       remarks
# 0          NaN    NaN           NaN
# ...

# %%
df_original = df.copy()

# %%
df.info()
# The ds shape is 92650 records and 15 columns.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92650 entries, 0 to 92649
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              92650 non-null  datetime64[ns]
#  1   generation_mw         92650 non-null  float64
#  2   demand_mw             92650 non-null  int64
#  3   load_shedding         92650 non-null  int64
#  4   gas                   92650 non-null  int64
#  5   liquid_fuel           92650 non-null  int64
#  6   coal                  92650 non-null  int64
#  7   hydro                 92650 non-null  int64
#  8   solar                 70517 non-null  float64
#  9   wind                  18676 non-null  float64
#  10  india_bheramara_hvdc  92650 non-null  int64
#  11  india_tripura         92650 non-null  int64
#  12  india_adani           7338 non-null   float64
#  13  nepal                 5351 non-null   float64
# ...

# %% [markdown]
# ### Finding issues in the DS:

# %%
# Let's check the missing value
df.isnull().sum().sort_values(ascending=False)
# Out:
# nepal                   87299
# remarks                 86257
# india_adani             85312
# wind                    73974
# solar                   22133
# datetime                    0
# generation_mw               0
# demand_mw                   0
# load_shedding               0
# gas                         0
# liquid_fuel                 0
# coal                        0
# hydro                       0
# india_bheramara_hvdc        0
# india_tripura               0
# dtype: int64

# %%
# let's check, do I have duplicated timestamp values?
df['datetime'].duplicated(keep='first').sum()
# Out:
# 432

# %%
# duplicate rows
df.duplicated().sum()
# Out:
# 160

# %%
# let's check the time range of the data. 
print(df['datetime'].min())
print(df['datetime'].max())
# the time range is almost 10 years
# 92650/8760 is around 10.5 years
# Out:
# 2015-04-19 00:00:00
# 2025-06-17 12:00:00

# %%
# from first cell that  I noticed that datetime is not sorted.
# Sorting the datetime 
df['datetime'] = pd.to_datetime(df['datetime'])
df = df.sort_values('datetime').reset_index(drop=True)
df.head()
# Out:
#              datetime  generation_mw  demand_mw  load_shedding  gas  \
# 0 2015-04-19 00:00:00         4821.0       4821              0    0
# 1 2015-04-19 01:00:00         3612.0       3612              0    0
# 2 2015-04-19 02:00:00         3727.0       3727              0    0
# 3 2015-04-19 03:00:00         3632.0       3632              0    0
# 4 2015-04-19 04:00:00         3641.0       3641              0    0
#
#    liquid_fuel  coal  hydro  solar  wind  india_bheramara_hvdc  india_tripura  \
# 0            0     0      0    NaN   NaN                     0              0
# 1            0     0      0    NaN   NaN                     0              0
# 2            0     0      0    NaN   NaN                     0              0
# 3            0     0      0    NaN   NaN                     0              0
# 4            0     0      0    NaN   NaN                     0              0
#
#    india_adani  nepal remarks
# 0          NaN    NaN     NaN
# ...

# %%
df['datetime'].diff().value_counts().head(10)
# Out:
# datetime
# 0 days 01:00:00    83649
# 0 days 00:30:00     8336
# 0 days 00:00:00      432
# 0 days 02:00:00      178
# 0 days 03:00:00       11
# 0 days 01:30:00        8
# 0 days 10:00:00        4
# 0 days 11:00:00        4
# 0 days 07:00:00        4
# 0 days 12:00:00        4
# Name: count, dtype: int64

# %%
# The ds has a lot of missing values and duplicated values.
# For wind, india_bheram, india_adani and nepal columns, the missing values are a lot. 
# timestamp has duplicated values
# the time gap between the row is not consistent, data is not recorded at 1 hour interval. 
# the time series is mixed one hour and half hour.

# %% [markdown]
# ### Handling for each issue in the DS

# %%
# Dropping duplicated rows and duplicated timestamps
print(f"Shape of DS before dropping duplicates: {df.shape}")
df = df.drop_duplicates()
df = df[~df['datetime'].duplicated(keep='first')].reset_index(drop=True)
print(f"Shape of DS after dropping duplicates: {df.shape}")
# Out:
# Shape of DS before dropping duplicates: (92650, 15)
# Shape of DS after dropping duplicates: (92218, 15)

# %%
# Dropping the missing values
# Nepal, remarks, india_adani and wind have a lot of missing values, the best way to handle this is to drop these columns.
df= df.drop(['remarks', 'nepal', 'india_adani', 'wind'], axis=1)

# Making the time series consistent by resampling 
df = df.set_index('datetime').resample('h').mean().reset_index()
# After resampling, I noticed that new missing values are created
# I ckecked the ds and found that exactly 1308 hour that had zero rows
# resampling fills those hours, it creates nan rows for every column, because there is nothing to average.

print("Shape after resampling:", df.shape)
print("\nMissing values after resampling:")
print(df.isnull().sum().sort_values(ascending=False))
# Out:
# Shape after resampling: (89101, 11)
#
# Missing values after resampling:
# solar                   21571
# generation_mw            1051
# demand_mw                1051
# load_shedding            1051
# gas                      1051
# liquid_fuel              1051
# coal                     1051
# hydro                    1051
# india_bheramara_hvdc     1051
# india_tripura            1051
# datetime                    0
# dtype: int64

# %%
# let's check the how long consecutive missing hours 
hours_missing = df['generation_mw'].isnull()
hours_missing = hours_missing.groupby((hours_missing != hours_missing.shift()).cumsum()).cumsum()
hours_missing.max()  
# Here is a huge gap, 517 hours
# Out:
# 517

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89101 entries, 0 to 89100
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              89101 non-null  datetime64[ns]
#  1   generation_mw         88050 non-null  float64
#  2   demand_mw             88050 non-null  float64
#  3   load_shedding         88050 non-null  float64
#  4   gas                   88050 non-null  float64
#  5   liquid_fuel           88050 non-null  float64
#  6   coal                  88050 non-null  float64
#  7   hydro                 88050 non-null  float64
#  8   solar                 67530 non-null  float64
#  9   india_bheramara_hvdc  88050 non-null  float64
#  10  india_tripura         88050 non-null  float64
# dtypes: datetime64[ns](1), float64(10)
# memory usage: 7.5 MB

# %%
# To fill the missing hours, I am gonna use interpolate method.
# All my ds columns are numeric, which is good.
# I am gonna set the limit to 24, because I have a huge gap of 517 hours.
# I will have still missing hours. 
df = df.set_index('datetime')
df = df.interpolate(method='time', limit=24)
df = df.reset_index()
df.isnull().sum().sort_values(ascending=False)
# Out:
# solar                   21248
# generation_mw             495
# demand_mw                 495
# load_shedding             495
# gas                       495
# liquid_fuel               495
# coal                      495
# hydro                     495
# india_bheramara_hvdc      495
# india_tripura             495
# datetime                    0
# dtype: int64

# %%
# I will fix the remaining missing hours by median.
df = df.set_index('datetime')
fill = df.drop(columns='solar').groupby([df.index.hour, df.index.month]).transform('median')
df = df.fillna(fill).reset_index()
df.isnull().sum().sort_values(ascending=False)
# Out:
# solar                   21248
# datetime                    0
# generation_mw               0
# demand_mw                   0
# load_shedding               0
# gas                         0
# liquid_fuel                 0
# coal                        0
# hydro                       0
# india_bheramara_hvdc        0
# india_tripura               0
# dtype: int64

# %%
# Since the solar column has less missing values, I did not drop it like the other columns.
miss_solar = df['solar'].isna()
missing_by_year = (miss_solar.groupby(df['datetime'].dt.year).mean()*100).round(1)
missing_by_hour = (miss_solar.groupby(df['datetime'].dt.hour).mean()*100).round(1)
print("Missing values by year:")
print(missing_by_year)
print("\nMissing values by hour:")
print(missing_by_hour)
# Out:
# Missing values by year:
# datetime
# 2015    100.0
# 2016    100.0
# 2017     71.9
# 2018      0.0
# 2019      0.0
# 2020      0.0
# 2021      0.0
# 2022      0.0
# 2023      0.0
# 2024      0.0
# 2025      0.0
# Name: solar, dtype: float64
#
# Missing values by hour:
# datetime
# 0     23.9
# 1     23.9
# 2     23.9
# 3     23.9
# 4     23.9
# 5     23.9
# 6     23.8
# 7     23.8
# 8     23.8
# 9     23.8
# 10    23.8
# 11    23.8
# 12    23.8
# 13    23.8
# 14    23.8
# 15    23.8
# 16    23.8
# 17    23.8
# 18    23.8
# 19    23.8
# 20    23.9
# 21    23.9
# 22    23.8
# 23    23.8
# Name: solar, dtype: float64

# %%
# 2015 and 2016 have completely missing solar data
# 2017 has around 71% missing solar data
# after 2017, the missing is a lot less.
# I can drop ds before 2018, because of the huge missing values.
df = df[df['datetime'].dt.year >= 2018].reset_index(drop=True)
df.isnull().sum().sort_values(ascending=False)
# Out:
# datetime                0
# generation_mw           0
# demand_mw               0
# load_shedding           0
# gas                     0
# liquid_fuel             0
# coal                    0
# hydro                   0
# solar                   0
# india_bheramara_hvdc    0
# india_tripura           0
# dtype: int64

# %%
df.shape
# Out:
# (65389, 11)

# %%
df.head()
# Out:
#              datetime  generation_mw  demand_mw  load_shedding     gas  \
# 0 2018-01-01 00:00:00         5183.0     5183.0            0.0  4206.0
# 1 2018-01-01 01:00:00         4908.0     4908.0            0.0  4134.0
# 2 2018-01-01 02:00:00         4786.0     4786.0            0.0  4013.0
# 3 2018-01-01 03:00:00         4599.0     4599.0            0.0  3838.0
# 4 2018-01-01 04:00:00         4594.0     4594.0            0.0  3878.0
#
#    liquid_fuel   coal  hydro  solar  india_bheramara_hvdc  india_tripura
# 0        330.0  179.0   75.0    0.0                 209.0           70.0
# 1        249.0  180.0   75.0    0.0                 209.0           64.0
# 2        249.0  177.0   73.0    0.0                 209.0           66.0
# 3        231.0  185.0   73.0    0.0                 209.0           64.0
# 4        231.0  185.0   73.0    0.0                 209.0           64.0

# %%
df.describe()
# Out:
#                   datetime  generation_mw      demand_mw  load_shedding  \
# count                65389   6.538900e+04   65389.000000   65389.000000
# mean   2021-09-24 06:00:00   1.046489e+04    9592.769789     108.871714
# min    2018-01-01 00:00:00   2.360000e+02       6.000000       0.000000
# 25%    2019-11-13 03:00:00   7.708300e+03    7709.000000       0.000000
# 50%    2021-09-24 06:00:00   9.370000e+03    9396.000000       0.000000
# 75%    2023-08-06 09:00:00   1.120800e+04   11349.500000       0.000000
# max    2025-06-17 12:00:00   6.452650e+07  121000.000000   45068.000000
# std                    NaN   2.523135e+05    2609.004813     386.314902
#
#                 gas   liquid_fuel          coal         hydro         solar  \
# count  65389.000000  6.538900e+04  65389.000000  65389.000000  65389.000000
# mean    5392.267281  2.201076e+03   1276.897035     88.842198     49.807573
# min        0.000000  0.000000e+00      0.000000      0.000000      0.000000
# ...

# %%
# the max value of generation_mw is 64526500 mw. this is a huge number, kind of impossible.
# Also same for demand_mm and liquid_fuel.
# Peak values of solar is during the day time, which is correct. 
# I can see the outliers in the DS.

# %%
# Visualizing the distribution of the all the columns to check the outliers better 
energy_columns  = df.select_dtypes(include="number").melt(var_name='column', value_name='value')
g = sns.catplot(data=energy_columns,y="value", col="column",kind="boxen", col_wrap= 2, sharey=False, height=3.2, aspect=1.5)
g.set_titles("{col_name}")
plt.show()
# Sources of the code:https://seaborn.pydata.org/generated/seaborn.catplot.html

# %%
# let's find average solar by hour to check the peak values
hourly_solar = (df.groupby(df['datetime'].dt.hour)['solar'].agg(['mean', 'median', 'max']))
hourly_solar
# Out:
#                 mean  median     max
# datetime
# 0           0.184440     0.0   167.0
# 1           0.327266     0.0   513.0
# 2           0.128000     0.0   140.0
# 3           0.240844     0.0   142.0
# 4           0.116459     0.0    86.0
# 5           2.816343     0.0   106.0
# 6          21.647735     7.0   606.0
# 7          61.452642    33.0   375.0
# 8         105.784374    61.0   909.0
# 9         144.597541    81.0  2998.0
# 10        164.711490    96.0   672.0
# 11        173.353615   100.0   698.0
# 12        165.979300    96.0   683.0
# 13        145.853373    83.0   603.0
# 14        112.352069    66.0   805.0
# 15         66.745317    37.0   554.0
# 16         24.439923     7.3   181.0
# 17          3.724929     0.0   208.0
# 18          0.103548     0.0    80.0
# 19          0.203495     0.0   215.0
# 20          0.135913     0.0    90.0
# 21          0.110320     0.0   134.0
# 22          0.129396     0.0   166.0
# 23          0.172260     0.0   184.0

# %%
# As I mentioned before, there are some outliers in the DS and the catplot shows  the outliers.
# I am gonna handle the outliers.
# I need to  remove only the peak values. 
columns = [column for column in df.columns if column != 'solar' and column != 'datetime']
q1 = df[columns].quantile(0.25)
q3 = df[columns].quantile(0.75)
upper = q3 + 3 * (q3 - q1)

# Replacing the outliers with NaN values and then I will handle the missing values by interpolation.
for col in upper[q3 > q1].index:
    df.loc[df[col] > upper[col], col] = np.nan

# In the above cell, I mentioned that solar has peak values during the day time, So I am gonna 
# creating dayttime mask
# In previous cell, I found that the peak values of solar is between 6 am to 4 pm, so I am gonna use this time range 
day = df['datetime'].dt.hour.between(6, 16)
q1_solar = df.loc[day, 'solar'].quantile(0.25)
q3_solar= df.loc[day, 'solar'].quantile(0.75)
df.loc[day &(df['solar']>q3_solar +3*(q3_solar -q1_solar)),'solar'] = np.nan
df = df.set_index('datetime').interpolate('time', limit=5).reset_index()

# %% [markdown]
# ### Feature engineering

# %%
# The target variable is  demand_mw.
#  generation_mw and load_shedding are leakage columns. 
df = df.drop(['generation_mw', 'load_shedding'], axis=1)

# %%
# These two columns can be merged : india_bheramara_hvdc + india_tripura as one column, import_power
# I have three fossil fuel columns, so I can combine them into one column, fossil_fuel: gas + liquid_fuel + coal
# Same for the renewable energy columns, I can combine them into one column, renewable_energy: solar + hydro

df['hour'] = df['datetime'].dt.hour
df['month']= df['datetime'].dt.month
df['year'] =df['datetime'].dt.year

df["import_power"] = df['india_bheramara_hvdc'] + df['india_tripura']
df["fossil_fuel"]= df['gas'] + df['liquid_fuel'] + df['coal']
df["renewable_energy"] = df['solar'] + df['hydro']

df = df.drop(['india_bheramara_hvdc', 'india_tripura', 'gas', 'liquid_fuel', 'coal', 'solar', 'hydro', 'datetime'], axis=1)

# %%
features = df.drop(['demand_mw'], axis=1)
target = df['demand_mw']
corr_to_target = features.corrwith(target).abs().sort_values(ascending=False).round(3)
sns.heatmap(features.corr().round(2), annot=True, cmap='vlag')
plt.show()

# %%
# Variance Inflation Factor: 
vif_data = df.drop(['demand_mw'], axis=1)
vif = pd.DataFrame({'feature': vif_data.columns,'VIF':[variance_inflation_factor(vif_data.values, i)
                   for i in range(len(vif_data.columns))]}).sort_values('VIF', ascending=False)
vif
# Out:
#             feature        VIF
# 4       fossil_fuel  28.599466
# 3      import_power  23.011141
# 2              year  22.936494
# 1             month   4.531640
# 0              hour   4.108864
# 5  renewable_energy   2.585973

# %%
#  I can drop import_power,  and year, because they have high VIF values.
df = df.drop(['import_power', 'year'], axis=1)

# %%
features = df.drop(['demand_mw'], axis=1)
target = df['demand_mw']
mi_scores = mutual_info_regression(features, target)
mi_scores = pd.Series(mi_scores, index=features.columns).sort_values(ascending=False).round(3)
print("Mutual Information Scores:")
print(mi_scores)
# Out:
# Mutual Information Scores:
# fossil_fuel         1.980
# month               0.257
# renewable_energy    0.227
# hour                0.109
# dtype: float64

# %%
df_optimized = df.copy()

# %%
# The optimized dataset is clearly cleaner and simpler than the original one.
# The main improvements were:  duplicate handling, handling missing values, filling hours gaps, handling outliers, and feature grouping.
# I tried to reduce noise and redundancy in the DS.
# the most effective methods were hourly resampling, interpolation, grouped median filling, feature grouping, VIF, and mutual information.

# %% [markdown]
# ### Comparing original vs cleaned dataset

# %%
df_original['hour'] = df_original['datetime'].dt.hour
df_original['month'] = df_original['datetime'].dt.month

print(df_original[['demand_mw','hour','month']].corr().round(3))
print()
print(df_optimized[['demand_mw','hour','month']].corr().round(3))
# Out:
#            demand_mw   hour  month
# demand_mw      1.000  0.216 -0.006
# hour           0.216  1.000  0.000
# month         -0.006  0.000  1.000
#
#            demand_mw  hour  month
# demand_mw      1.000  0.25  0.068
# hour           0.250  1.00  0.000
# month          0.068  0.00  1.000

# %%
stats_columns = ['demand_mw', 'hour', 'month']
compare_stats = (df_original[stats_columns].agg(['mean', 'median', 'std', 'var']).T.add_suffix('_before')
                 .join(df_optimized[stats_columns].agg(['mean', 'median', 'std', 'var']).T.add_suffix('_after')).round(2))
compare_stats
# Out:
#            mean_before  median_before  std_before  var_before  mean_after  \
# demand_mw      8819.65         8422.0     2772.15  7684816.22     9585.39
# hour             11.77           12.0        6.89       47.53       11.50
# month             6.53            6.0        3.41       11.63        6.32
#
#            median_after  std_after   var_after
# demand_mw        9396.0    2475.40  6127582.71
# hour               11.0       6.92       47.92
# month               6.0       3.45       11.92

# %%
corr_columns = ['demand_mw', 'hour', 'month', 'fossil_fuel', 'renewable_energy']
corr_before = (df_original.assign(fossil_fuel=lambda d:d['gas']+d['liquid_fuel'] + d['coal'],
                renewable_energy=lambda d: d['solar']+d['hydro'])[corr_columns].corr()['demand_mw'].round(3))

corr_after = df_optimized[corr_columns].corr()['demand_mw'].round(3)
print(corr_before)
print()
print(corr_after)
# I used QWEN MAX3 for debugging.
# Out:
# demand_mw           1.000
# hour                0.216
# month              -0.006
# fossil_fuel         0.021
# renewable_energy    0.271
# Name: demand_mw, dtype: float64
#
# demand_mw           1.000
# hour                0.250
# month               0.068
# fossil_fuel         0.967
# renewable_energy    0.331
# Name: demand_mw, dtype: float64

# %%
# I compared the original and optimized DSs using summary statistics and correlations.
# The optimized ds became much simpler and more focused, but it also moved clearly away from the original data distribution.
# the optimized ds has higher central demand values but lower spread than the original ds.

# I would say the optimization worked well for simplification and variable reduction, but not perfectly for realism,
# the optimized ds is not very close to the original ds anymore, especially in the distribution of demand_mw and in the very strong dependency between demand_mw and fossil_fuel.
